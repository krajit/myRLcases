# %%
from ray.rllib.agents.mbmpo import MBMPOTrainer

# %%
from ray.rllib.examples.env.mbmpo_env import CartPoleWrapper
from ray.rllib.examples.env.mbmpo_env import PendulumWrapper

from ray import tune

configTuned = {
        "env":CartPoleWrapper,  
       "framework": "torch",
        #"horizon": 200,
        "num_envs_per_worker": 20,
        "inner_adaptation_steps": 1,
        "maml_optimizer_steps": 8,
        "gamma": 0.99,
        "lambda": 1.0,
        "lr": 0.001,
        "clip_param": 0.5,
        "kl_target": 0.003,
        "kl_coeff": 0.0000000001,
        "num_workers": 2,
        "num_gpus": 0,
        "inner_lr": 0.001,
        "clip_actions": False,
        "num_maml_steps": 15,
        "model": {
            "fcnet_hiddens": [32, 32],
            "free_log_std": True,
        }        
}

# %%
trainer = MBMPOTrainer(config=configTuned)
# Out:
# 2022-08-16 15:49:20,031	INFO services.py:1470 -- View the Ray dashboard at http://127.0.0.1:8269
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/envs/rllib-stable/lib/python3.9/site-packages/ray/rllib/agents/trainer.py:935, in Trainer.setup(self, config)
#     934 try:
# --> 935     self._init(self.config, self.env_creator)
#     936 # New design: Override `Trainable.setup()` (as indented by Trainable)
#     937 # and do or don't call super().setup() from within your override.
#     938 # By default, `super().setup()` will create both worker sets:
#    (...)
#     941 # parallel to training.
#     942 # TODO: Deprecate `_init()` and remove this try/except block.
#
# File ~/anaconda3/envs/rllib-stable/lib/python3.9/site-packages/ray/rllib/agents/trainer.py:1074, in Trainer._init(self, config, env_creator)
# ...
